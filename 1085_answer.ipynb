# %%
#sol1
x, y, w, h = input().split()
x=int(x)
y=int(y)
w=int(w)
h=int(h)

distance=[]
distance.append(x)
distance.append(y)
distance.append(w-x)
distance.append(h-y)

ans = min(distance)
print(ans)
# Out:
# 161 181 762 375
# [161, 181, 601, 194]
# 161

# %%
#sol2
x, y, w, h =map(int,input().split())
print(min(x,y,w-x,h-y))
# Out:
# 161 181 762 375
# 161
