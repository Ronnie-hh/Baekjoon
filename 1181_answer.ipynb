# %%
words=[]
N = int(input())

for n in range(N):
  words.append(input())

words=list(set(words)) #중복 제거
words.sort() #알파벳 순으로 정렬
words.sort(key=len) #요소 길이 순으로 정렬

for i in words:
  print(i)
# Out:
# 13
# but
# i
# wont
# hesitate
# no
# more
# no
# more
# it
# cannot
# wait
# im
# yours
# i
# im
# it
# no
# but
# more
# wait
# wont
# yours
# cannot
# hesitate
